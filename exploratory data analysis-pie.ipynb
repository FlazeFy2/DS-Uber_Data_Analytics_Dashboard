# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ncr_ride_bookings.csv")

# Exploratory Data Analysis (EDA) - Pie Chart Most Context for Nonconditional Data
target_col = ['Booking Status','Vehicle Type','Payment Method','Driver Cancellation Reason']

for dt in target_col:
    # Dataset
    top_context = df[dt].value_counts()
    
    # Pie Chart
    plt.figure(figsize=(8,8))
    top_context.plot.pie(autopct='%1.1f%%', startangle=90)
    plt.title(f"Comparison Of {dt}")
    plt.ylabel("")
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution by Rate Category
df = pd.read_csv("ncr_ride_bookings.csv")

# Convert Rating to Rating Category
def categorize_rating(rate):
    if not pd.isna(rate):
        if rate >= 4:
            return "Perfect"
        elif rate >= 3:
            return "Normal"
        else:
            return "Low"
    else:
        return "Not Rated"

df["Rate Category"] = df["Customer Rating"].apply(categorize_rating)

# Count the number of booking in each category
stay_counts = df["Rate Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
stay_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution by Rate Category")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution by Time Category
df = pd.read_csv("ncr_ride_bookings.csv")

# Convert Time to datetime
df["Hour"] = pd.to_datetime(df["Time"], format="%H:%M:%S").dt.hour

# Convert Time to Time Category
def categorize_time(hour):
    if 5 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 21:
        return "Evening"
    else:
        return "Night"

# Count the number of booking
df["Time Category"] = df["Hour"].apply(categorize_time)

time_counts = df["Time Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
time_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution by Time Category")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution by Rush Hour vs Normal Hour
df = pd.read_csv("ncr_ride_bookings.csv")

# Convert Time to datetime
df["Hour"] = pd.to_datetime(df["Time"], format="%H:%M:%S").dt.hour

# Convert Hour to Time Category
def categorize_time(hour):
    if (6 <= hour < 9) or (16 <= hour < 21):
        return "Rush Hour"
    else:
        return "Normal Hour"

df["Time Category"] = df["Hour"].apply(categorize_time)

# Count the number of booking
time_counts = df["Time Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
time_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Rush Hour vs Normal Hour")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution : AM vs PM
df = pd.read_csv("ncr_ride_bookings.csv")

# Convert Time to datetime
df["Hour"] = pd.to_datetime(df["Time"], format="%H:%M:%S").dt.hour

# Convert Hour to Time Category
def categorize_time(hour):
    if hour <= 12:
        return "AM"
    else:
        return "PM"

df["Time Category"] = df["Hour"].apply(categorize_time)

# Count the number of booking
time_counts = df["Time Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
time_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: AM vs PM")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution : Is Cashless?
df = pd.read_csv("ncr_ride_bookings.csv")


# Categorize Payment
def categorize_payment(payment):
    if payment == "Cash":
        return "Yes"
    else:
        return "No"

df["Is Cashless"] = df["Payment Method"].apply(categorize_payment)

# Count the number of booking
time_counts = df["Is Cashless"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
time_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution : Is Cashless?")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution by Lunch Time vs Commute Time
df = pd.read_csv("ncr_ride_bookings.csv")

# Convert Time to datetime
df["Hour"] = pd.to_datetime(df["Time"], format="%H:%M:%S").dt.hour

# Convert Hour to Activity Category (Lunch, Go to Work, Go Home, Other)
def categorize_activity(hour):
    if 6 <= hour <= 9:
        return "Morning Commute (Go to Work/School)"
    elif 11 <= hour <= 14:
        return "Lunch Time"
    elif 17 <= hour <= 20:
        return "Evening Commute (Go Home)"
    else:
        return "Other Hours"

df["Activity Category"] = df["Hour"].apply(categorize_activity)

# Count the number of booking
activity_counts = df["Activity Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
activity_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Lunch Time vs Commute Times")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution: Weekday vs Weekend
df = pd.read_csv("ncr_ride_bookings.csv")

# Convert Date to datetime
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d")

# Convert Date to Weekday Category
def categorize_day(date):
    if date.weekday() < 5:   # 0=Monday, 4=Friday
        return "Weekday"
    else:                   # 5=Saturday, 6=Sunday
        return "Weekend"

df["Day Category"] = df["Date"].apply(categorize_day)

# Count the number of booking
day_counts = df["Day Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
day_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Weekday vs Weekend")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution: Even vs Odd Date
df = pd.read_csv("ncr_ride_bookings.csv")

# Convert Date to datetime
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d")

# Convert Date to Even/Odd Category
def categorize_day(date):
    if date.day % 2 == 0:    # Even date
        return "Even Date"
    else:                    # Odd date
        return "Odd Date"

df["Day Category"] = df["Date"].apply(categorize_day)

# Count the number of booking
day_counts = df["Day Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
day_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Even vs Odd Date")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution: Bike vs Car
df = pd.read_csv("ncr_ride_bookings.csv")

# Categorize Type
def categorize_type(val):
    if val == "Bike" or val == "eBike":   
        return "Bike"
    else:                   
        return "Car"

df["Vehicle Group"] = df["Vehicle Type"].apply(categorize_type)

# Count the number of booking
data_counts = df["Vehicle Group"].value_counts()

# Pie Chart
plt.figure(figsize=(6, 6))
data_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Bike vs Car")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution: Go Sedan vs Premier Sedan
df = pd.read_csv("ncr_ride_bookings.csv")

# Keep only sedan type
df = df[(df["Vehicle Type"] == "Premier Sedan") | (df["Vehicle Type"] == "Go Sedan")]

# Count the number of booking
data_counts = df["Vehicle Type"].value_counts()

# Pie Chart
plt.figure(figsize=(6, 6))
data_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Go Sedan vs Premier Sedan")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution: Card Payment Method
df = pd.read_csv("ncr_ride_bookings.csv")

# Categorize Type
def categorize_type(val):
    if val != "Debit Card" and val != "Credit Card":   
        return "Others"
    else:                   
        return val

df["Card Payment Method"] = df["Payment Method"].apply(categorize_type)

# Count the number of booking
data_counts = df["Card Payment Method"].value_counts()

# Pie Chart
plt.figure(figsize=(6, 6))
data_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Card Payment Method")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution: Go Vehicle Type
df = pd.read_csv("ncr_ride_bookings.csv")

# Categorize Type
def categorize_type(val):
    if val != "Go Sedan" and val != "Go Mini":   
        return "Others"
    else:                   
        return val

df["Go Vehicle Type"] = df["Vehicle Type"].apply(categorize_type)

# Count the number of booking
data_counts = df["Go Vehicle Type"].value_counts()

# Pie Chart
plt.figure(figsize=(6, 6))
data_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Go Vehicle Type")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution : Booking Value Category
df = pd.read_csv("ncr_ride_bookings.csv")

# Booking Value Category
def categorize_booking(price):
    if price <= 500:
        return "Cheap"
    elif price <= 1000:
        return "Moderate"
    else:
        return "Expensive"

df["Booking Value Category"] = df["Booking Value"].apply(categorize_booking)

# Count the number of booking
time_counts = df["Booking Value Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
time_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Booking Value Category")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution : Avg CTAT Category
df = pd.read_csv("ncr_ride_bookings.csv")

print(df['Avg CTAT'].min())
# Booking Value Avg CTAT
def categorize_ctat(val):
    if val <= 20:
        return "Low"
    elif val <= 40:
        return "Medium"
    else:
        return "High"

df["Avg CTAT Category"] = df["Avg CTAT"].apply(categorize_ctat)

# Count the number of booking
time_counts = df["Avg CTAT Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
time_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Avg CTAT Category")
plt.ylabel("")
plt.tight_layout()
plt.show()
# Out:
# 10.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
# Exploratory Data Analysis (EDA) - Pie Chart Booking Distribution : Avg VTAT Category
df = pd.read_csv("ncr_ride_bookings.csv")

print(df['Avg VTAT'].min())
# Booking Value Avg CTAT
def categorize_vtat(val):
    if val <= 10:
        return "Low"
    elif val <= 20:
        return "Medium"
    else:
        return "High"

df["Avg VTAT Category"] = df["Avg VTAT"].apply(categorize_vtat)

# Count the number of booking
time_counts = df["Avg VTAT Category"].value_counts().sort_index()

# Pie Chart
plt.figure(figsize=(6, 6))
time_counts.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Booking Distribution: Avg VTAT Category")
plt.ylabel("")
plt.tight_layout()
plt.show()
# Out:
# 2.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ncr_ride_bookings.csv")

# Exploratory Data Analysis (EDA) - Pie Chart Comparison Of Vehicle Type Used To Airport
# Takes only airport location
airport_rides = df[
    df['Pickup Location'].str.contains('airport', case=False, na=False) |
    df['Drop Location'].str.contains('airport', case=False, na=False)
]

# Dataset
top_context = airport_rides['Vehicle Type'].value_counts()

# Pie Chart
plt.figure(figsize=(8,8))
top_context.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title(f"Comparison Of Vehicle Type Used To Airport")
plt.ylabel("")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ncr_ride_bookings.csv")

# Exploratory Data Analysis (EDA) - Pie Chart Comparison Of Vehicle Type Used To Public Space (Park, Garden)
# Takes only public space location
airport_rides = df[
    df['Pickup Location'].str.contains('park|garden', case=False, na=False) |
    df['Drop Location'].str.contains('park|garden', case=False, na=False)
]

# Dataset
top_context = airport_rides['Vehicle Type'].value_counts()

# Pie Chart
plt.figure(figsize=(8,8))
top_context.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title(f"Comparison Of Vehicle Type Used To Public Space (Park, Garden)")
plt.ylabel("")
plt.show()
